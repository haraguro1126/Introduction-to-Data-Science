# %% [markdown]
# <a href="https://colab.research.google.com/github/haraguro1126/Introduction-to-Data-Science/blob/master/20200529.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_1.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/109TN5jTHL4j4SC1wfTLpQyRD_9rMK5XS
"""

sample_history = []
while True:
    random_integer = sample(range(1, 1001), 1)[0]
    sample_history.append(random_integer)
    if random_integer % 56 == 0:
        break
print(sample_history)
print(len(sample_history))

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_2.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1rUdtGsOuik05Z-GRfgDXOjee7RUGhxnA
"""

n_vowels = 0 
for i in 'azcbobobegghak':
    if i in ['a', 'e', 'i', 'o', 'u']:
        #print(i)
        n_vowels += 1
print(n_vowels)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_3.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1oQ1WJbaXDBahakkNvp1Ln6ylSg_CWRBC
"""

test_str = 'azcbobobegghak'
n_char = len(test_str)
n_bobs = 0
for i in range(n_char - 2):
    #print(test_str[i:i+3])
    if test_str[i:i+3] == 'bob':
        n_bobs += 1
print(n_bobs)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_4.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1qLRhpW-pc1o9CjpNXUJ-fR-1jrr9FCtf
"""

x = list(range(1, 101))
N = len(x)
x_bar = sum(x) / N
sse = 0
for xi in x:
    #error = xi - x_bar
    squared_error = (xi - x_bar)**2
    sse += squared_error #sse = sse + squared_error
sample_mse = sse / (N-1)
sample_stdev = sample_mse**(0.5)
print(sample_stdev)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_5.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1zFVdqoZ0lQs7DzfgkNhtwCULFsJVI9Zc
"""

from statistics import stdev

stdev(range(1, 101)) # [1, 2, 3, ..., 100]
© 2020 GitHub, Inc.

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_6.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/16XNR-NZ4HdxWehmVRNiSBhC__PRRg-uT
"""

def get_fahrenheit(x):
    """
    Transform a Celsius degree into  Farenheit scale
    """
    fah = x * 9/5 + 32
    return fah

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_7.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1s2Pr4Iu7MHnW5yk0NXneh-c4chYMLaD0
"""

get_fahrenheit(32)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_8.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1zm6bDGyLyLCNQYNvW27uu__3X1R1J_M2
"""

def get_bmi(height, weight):
    """
    Calculate BMI based on height and weight
    """
    height = height / 100
    bmi = weight / height**2
    return bmi

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_9.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1rq-NBDyHdhblOuWTAT2OsHND2Kyu5Iir
"""

get_bmi(198, 129)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_10.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1dhepKtnOiPFlfJ5SPUpgGTN2ZYB_VpGF
"""

get_bmi(216, 147)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_11.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1IqnkUaKhkBHgfPdImiNFE4BDH2uB-hIK
"""

def is_prime(x):
    """
    Returns True if x is a prime, or returns False
    """
    divisors = []
    for i in range(1, x+1):
        if x % i == 0:
            divisors.append(i)
    n_divisors = len(divisors)
    return n_divisors == 2

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_12.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1sMWXG7Pq1Nws_c7jJWUW9_glycR08-3l
"""

is_prime(1)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_13.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1bbrSZD5DdKNR20VKf8ykASq1VoLgTIsx
"""

is_prime(2)

# %%
# -*- coding: utf-8 -*-
"""IDS_20200529_14.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1QRhakHxB6J1oht4-k6znCvbjwZlBMQbc
"""

is_prime(8)
